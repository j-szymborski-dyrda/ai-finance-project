# %%
# Model Comparison — Bar Moan Bank Portfolio
# Run this notebook after all teammates have run their own notebooks and saved their summaries to data/.

# ── Imports ────────────────────────────────────────────────
from evaluation import compare_models

# %%
# ── Compare All Models ─────────────────────────────────────
# Automatically picks up all summary_*.json files in data/
# Make sure all teammates have run their notebooks first

compare_models()
# Out:
# ...
#   MODEL COMPARISON
# ...
# <style type="text/css">
# </style>
# <table id="T_ef565">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef565_level0_col0" class="col_heading level0 col0" >benchmark</th>
#       <th id="T_ef565_level0_col1" class="col_heading level0 col1" >benchmark_exitrule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef565_level0_row0" class="row_heading level0 row0" >Annual net revenue (full)</th>
#       <td id="T_ef565_row0_col0" class="data row0 col0" >12.39%</td>
#       <td id="T_ef565_row0_col1" class="data row0 col1" >11.67%</td>
#     </tr>
#     <tr>
#       <th id="T_ef565_level0_row1" class="row_heading level0 row1" >Sharpe ratio (full)</th>
#       <td id="T_ef565_row1_col0" class="data row1 col0" >1.2085</td>
#       <td id="T_ef565_row1_col1" class="data row1 col1" >1.2534</td>
#     </tr>
#     <tr>
#       <th id="T_ef565_level0_row2" class="row_heading level0 row2" >Worst month</th>
# ...

# %%
# ── Cell 4: Plot Cumulative Net Revenue ────────────────────
import importlib
import evaluation
importlib.reload(evaluation)
from evaluation import plot_cumulative_net_revenue

plot_cumulative_net_revenue()
# Out:
# Saved to data/plot_cumulative_net_revenue.png ✅

# %%
# ── Cell 5: Plot Crisis vs Normal ──────────────────────────
import importlib
import evaluation
importlib.reload(evaluation)
from evaluation import plot_crisis_vs_normal

plot_crisis_vs_normal()
# Out:
# Saved to data/plot_crisis_vs_normal.png ✅
