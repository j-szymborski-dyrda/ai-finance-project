# %%
# Model Comparison — Bar Moan Bank Portfolio
# Run this notebook after all teammates have run their own notebooks and saved their summaries to data/.

# ── Imports ────────────────────────────────────────────────
from evaluation import compare_models

# %%
# ── Compare All Models ─────────────────────────────────────
# Automatically picks up all summary_*.json files in data/
# Make sure all teammates have run their notebooks first

compare_models()
# Out:
# =======================================================
#   MODEL COMPARISON
# =======================================================
# <style type="text/css">
# </style>
# <table id="T_72661">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72661_level0_col0" class="col_heading level0 col0" >benchmark</th>
#       <th id="T_72661_level0_col1" class="col_heading level0 col1" >benchmark_exitrule</th>
#       <th id="T_72661_level0_col2" class="col_heading level0 col2" >lasso</th>
#       <th id="T_72661_level0_col3" class="col_heading level0 col3" >model_a</th>
#       <th id="T_72661_level0_col4" class="col_heading level0 col4" >ridge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72661_level0_row0" class="row_heading level0 row0" >Annual net revenue (full)</th>
#       <td id="T_72661_row0_col0" class="data row0 col0" >12.39%</td>
#       <td id="T_72661_row0_col1" class="data row0 col1" >11.67%</td>
#       <td id="T_72661_row0_col2" class="data row0 col2" >11.23%</td>
#       <td id="T_72661_row0_col3" class="data row0 col3" >11.54%</td>
#       <td id="T_72661_row0_col4" class="data row0 col4" >11.13%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row1" class="row_heading level0 row1" >Sharpe ratio (full)</th>
#       <td id="T_72661_row1_col0" class="data row1 col0" >1.2085</td>
#       <td id="T_72661_row1_col1" class="data row1 col1" >1.2534</td>
#       <td id="T_72661_row1_col2" class="data row1 col2" >1.0465</td>
#       <td id="T_72661_row1_col3" class="data row1 col3" >1.0567</td>
#       <td id="T_72661_row1_col4" class="data row1 col4" >1.0361</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row2" class="row_heading level0 row2" >Worst month</th>
#       <td id="T_72661_row2_col0" class="data row2 col0" >-16.02%</td>
#       <td id="T_72661_row2_col1" class="data row2 col1" >-16.02%</td>
#       <td id="T_72661_row2_col2" class="data row2 col2" >-14.34%</td>
#       <td id="T_72661_row2_col3" class="data row2 col3" >-15.66%</td>
#       <td id="T_72661_row2_col4" class="data row2 col4" >-14.29%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row3" class="row_heading level0 row3" >Best month</th>
#       <td id="T_72661_row3_col0" class="data row3 col0" >10.34%</td>
#       <td id="T_72661_row3_col1" class="data row3 col1" >9.69%</td>
#       <td id="T_72661_row3_col2" class="data row3 col2" >9.64%</td>
#       <td id="T_72661_row3_col3" class="data row3 col3" >10.16%</td>
#       <td id="T_72661_row3_col4" class="data row3 col4" >9.94%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row4" class="row_heading level0 row4" >Crisis avg/month</th>
#       <td id="T_72661_row4_col0" class="data row4 col0" >-0.91%</td>
#       <td id="T_72661_row4_col1" class="data row4 col1" >-1.07%</td>
#       <td id="T_72661_row4_col2" class="data row4 col2" >-0.92%</td>
#       <td id="T_72661_row4_col3" class="data row4 col3" >-1.08%</td>
#       <td id="T_72661_row4_col4" class="data row4 col4" >-0.94%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row5" class="row_heading level0 row5" >Normal avg/month</th>
#       <td id="T_72661_row5_col0" class="data row5 col0" >1.15%</td>
#       <td id="T_72661_row5_col1" class="data row5 col1" >1.10%</td>
#       <td id="T_72661_row5_col2" class="data row5 col2" >1.08%</td>
#       <td id="T_72661_row5_col3" class="data row5 col3" >1.12%</td>
#       <td id="T_72661_row5_col4" class="data row5 col4" >1.07%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row6" class="row_heading level0 row6" >Annual net revenue (OOS)</th>
#       <td id="T_72661_row6_col0" class="data row6 col0" >12.85%</td>
#       <td id="T_72661_row6_col1" class="data row6 col1" >10.94%</td>
#       <td id="T_72661_row6_col2" class="data row6 col2" >12.26%</td>
#       <td id="T_72661_row6_col3" class="data row6 col3" >12.35%</td>
#       <td id="T_72661_row6_col4" class="data row6 col4" >12.21%</td>
#     </tr>
#     <tr>
#       <th id="T_72661_level0_row7" class="row_heading level0 row7" >Sharpe ratio (OOS)</th>
#       <td id="T_72661_row7_col0" class="data row7 col0" >1.1696</td>
#       <td id="T_72661_row7_col1" class="data row7 col1" >1.0580</td>
#       <td id="T_72661_row7_col2" class="data row7 col2" >1.0819</td>
#       <td id="T_72661_row7_col3" class="data row7 col3" >1.0713</td>
#       <td id="T_72661_row7_col4" class="data row7 col4" >1.0748</td>
#     </tr>
#   </tbody>
# </table>
#                            benchmark  benchmark_exitrule     lasso   model_a  \
# Annual net revenue (full)   0.123855            0.116705  0.112299  0.115430
# Sharpe ratio (full)         1.208526            1.253359  1.046512  1.056737
# Worst month                -0.160244           -0.160244 -0.143447 -0.156639
# Best month                  0.103355            0.096861  0.096439  0.101636
# Crisis avg/month           -0.009077           -0.010667 -0.009159 -0.010752
# Normal avg/month            0.011537            0.011003  0.010783  0.011191
# Annual net revenue (OOS)    0.128505            0.109384  0.122648  0.123472
# Sharpe ratio (OOS)          1.169598            1.058046  1.081908  1.071256
#
#                               ridge
# Annual net revenue (full)  0.111302
# Sharpe ratio (full)        1.036075
# Worst month               -0.142926
# Best month                 0.099389
# Crisis avg/month          -0.009384
# Normal avg/month           0.010711
# Annual net revenue (OOS)   0.122095
# Sharpe ratio (OOS)         1.074840

# %%
# ── Cell 4: Plot Cumulative Net Revenue ────────────────────
import importlib
import evaluation
importlib.reload(evaluation)
from evaluation import plot_cumulative_net_revenue

plot_cumulative_net_revenue()
# Out:
# Saved to data/plot_cumulative_net_revenue.png ✅

# %%
# ── Cell 5: Plot Crisis vs Normal ──────────────────────────
import importlib
import evaluation
importlib.reload(evaluation)
from evaluation import plot_crisis_vs_normal

plot_crisis_vs_normal()
# Out:
# Saved to data/plot_crisis_vs_normal.png ✅

# %%
# ── Cell 6: Compare Predictions ────────────────────────────
# Only run this after Model A and B have run summarise_predictions()
# in their own notebooks and saved their predictions_*.json files
# to data/. Requires a 'predicted_vol' column in monthly_results.

import importlib
import evaluation
importlib.reload(evaluation)
from evaluation import compare_predictions

compare_predictions()
# Out:
# No prediction files found in data/. Run summarise_predictions() first.
